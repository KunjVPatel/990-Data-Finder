# %%
import os
import requests
import pandas as pd
import concurrent.futures

# %%
def einLookup(eins):
    results = []

    def fetch_data(ein):
        try:
            q = f'https://projects.propublica.org/nonprofits/api/v2/organizations/{ein}.json'
            response = requests.get(q)
            response.raise_for_status()
            data = response.json()
            # print(data)

            if 'filings_with_data' in data and data['filings_with_data']:
                filing_data = data['filings_with_data'][0]
                fiscal_year_end = filing_data.get('tax_prd_yr', 'N/A')

                total_revenue = filing_data.get('totrevenue', 'N/A')
                totfuncexpns = filing_data.get('totfuncexpns', 'N/A')
                net_revenue = total_revenue - totfuncexpns

                result = [
                    ein,
                    data['organization']['name'],
                    total_revenue,
                    fiscal_year_end,
                    filing_data.get('pdf_url', 'N/A'),
                    data['organization'].get('city', 'N/A'),
                    data['organization'].get('state', 'N/A'),
                    data['organization'].get('ntee_code', 'N/A'),
                    net_revenue,  # Add the calculated net revenue to the result
                    filing_data.get('formtype', 'N/A')
                ]
                return result
            else:
                print(f'No filing data found for EIN {ein}')
                return None
        except Exception as e:
            print(f'Error for EIN {ein}: {e}')
            return None

    with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
        results = list(executor.map(fetch_data, eins))

    results = [r for r in results if r is not None]

    return results

def einLoader():
    excel_file_path = "/home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Data/EIN.csv"
    einVal = pd.read_csv(excel_file_path)
    ein_list = [str(ein) for ein in einVal['EIN']]

    batch_folder = "/home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch"
    batch_size = 50
    length = len(ein_list)
    # length = 2

    for i in range(0, length, batch_size):
        batch = ein_list[i:i + batch_size]
        results = einLookup(batch)
        batch_filename = os.path.join(batch_folder, f'out_batch_{i // batch_size}.csv')
        csvWriter(batch_filename, results)

def csvWriter(filename, data):
    df = pd.DataFrame(data, columns=['EIN_value', 'Name', 'Gross_Revenue', 'Tax_Period_Year', 'PDF_URL', 'City', 'State', 'NTEE_Code', 'Net_Revenue', 'Form_Type'])
    df.to_csv(filename, index=False)
    print(f'Data successfully written to {filename}.')

# %%
if __name__ == "__main__":
    einLoader()
# Out:
# No filing data found for EIN 871824915
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_0.csv.
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_1.csv.
# No filing data found for EIN 920535709
# No filing data found for EIN 873810878
# No filing data found for EIN 832886466
# No filing data found for EIN 886650516
# No filing data found for EIN 841994814
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_2.csv.
# No filing data found for EIN 844321978
# No filing data found for EIN 756085383
# No filing data found for EIN 372006472
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_3.csv.
# No filing data found for EIN 882878709
# No filing data found for EIN 866495457
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_4.csv.
# No filing data found for EIN 852505655
# No filing data found for EIN 455009021
# No filing data found for EIN 852945150
# No filing data found for EIN 861211806
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_5.csv.
# No filing data found for EIN 846612115
# No filing data found for EIN 832871250
# No filing data found for EIN 844706116
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_6.csv.
# No filing data found for EIN 854313691
# No filing data found for EIN 824390775
# No filing data found for EIN 882487003
# No filing data found for EIN 856775101
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_7.csv.
# No filing data found for EIN 862596055
# No filing data found for EIN 873826522
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_8.csv.
# No filing data found for EIN 882108924
# No filing data found for EIN 854271699
# No filing data found for EIN 844321978
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_78.csv.
# No filing data found for EIN 273322123
# No filing data found for EIN 232929820
# No filing data found for EIN 873599288
# No filing data found for EIN 873014451
# No filing data found for EIN 882044446
# No filing data found for EIN 320638394
# No filing data found for EIN 872288081
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_79.csv.
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_80.csv.
# No filing data found for EIN 981509773
# No filing data found for EIN 852487977
# No filing data found for EIN 874078953
# No filing data found for EIN 813624766
# No filing data found for EIN 882110698
# No filing data found for EIN 873807146
# No filing data found for EIN 881403435
# No filing data found for EIN 872160314
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_81.csv.
# No filing data found for EIN 810750278
# No filing data found for EIN 311353439
# No filing data found for EIN 921044190
# No filing data found for EIN 376325303
# No filing data found for EIN 853295358
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_82.csv.
# No filing data found for EIN 921311288
# No filing data found for EIN 882696020
# No filing data found for EIN 862993778
# No filing data found for EIN 352701228
# No filing data found for EIN 863933313
# No filing data found for EIN 854069856
# No filing data found for EIN 871802689
# No filing data found for EIN 884417929
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_83.csv.
# No filing data found for EIN 873841291
# No filing data found for EIN 886778888
# No filing data found for EIN 882799445
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_84.csv.
# No filing data found for EIN 881296442
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_85.csv.
# No filing data found for EIN 854112741
# No filing data found for EIN 872934139
# No filing data found for EIN 873496357
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_86.csv.
# No filing data found for EIN 431961686
# No filing data found for EIN 873971342
# No filing data found for EIN 874153400
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_87.csv.
# No filing data found for EIN 863171002
# No filing data found for EIN 861430875
# No filing data found for EIN 883115293
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_88.csv.
# No filing data found for EIN 943286342
# No filing data found for EIN 816333277
# No filing data found for EIN 882572008
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_89.csv.
# No filing data found for EIN 884221243
# No filing data found for EIN 881855883
# No filing data found for EIN 881763763
# No filing data found for EIN 854340493
# No filing data found for EIN 881247586
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_90.csv.
# No filing data found for EIN 873580115
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_91.csv.
# No filing data found for EIN 872181921
# No filing data found for EIN 832543135
# No filing data found for EIN 841994814
# No filing data found for EIN 862944905
# No filing data found for EIN 845137603
# No filing data found for EIN 863833381
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_92.csv.
# No filing data found for EIN 873379542
# No filing data found for EIN 352701228
# No filing data found for EIN 881729194
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_93.csv.
# No filing data found for EIN 852274833
# No filing data found for EIN 237989378
# No filing data found for EIN 843778379
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_94.csv.
# No filing data found for EIN 854229466
# No filing data found for EIN 383685911
# No filing data found for EIN 883572493
# No filing data found for EIN 872224904
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_95.csv.
# No filing data found for EIN 882572008
# No filing data found for EIN 873194330
# No filing data found for EIN 854344387
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_96.csv.
# No filing data found for EIN 843261541
# No filing data found for EIN 882782318
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_97.csv.
# No filing data found for EIN 876900026
# No filing data found for EIN 856734106
# No filing data found for EIN 881119230
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_98.csv.
# No filing data found for EIN 464338677
# No filing data found for EIN 881961055
# No filing data found for EIN 872753486
# No filing data found for EIN 844409467
# No filing data found for EIN 843489172
# No filing data found for EIN 736091909
# No filing data found for EIN 371751439
# No filing data found for EIN 880741884
# Data successfully written to /home/dark/GitHub/Opportunity-Hack-KSJ/OpportunityHack/Batch/out_batch_99.csv.
